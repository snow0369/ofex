# %%
from ofex.hamiltonian import zz_1d, heisenberg_1d, heisenberg_1d_ring
from ofex.utils.chem import molecule_example

# %%
n_qubits = 4

# %%
print(zz_1d(n_qubits))
# Out:
# 1.0 [Z0 Z1] +
# 1.0 [Z1 Z2] +
# 1.0 [Z2 Z3]

# %%
print(heisenberg_1d(n_qubits))
# Out:
# 1.0 [X0 X1] +
# 1.0 [Y0 Y1] +
# 1.0 [Z0 Z1] +
# 1.0 [X1 X2] +
# 1.0 [Y1 Y2] +
# 1.0 [Z1 Z2] +
# 1.0 [X2 X3] +
# 1.0 [Y2 Y3] +
# 1.0 [Z2 Z3]

# %%
print(heisenberg_1d_ring(n_qubits))
# Out:
# 1.0 [X0 X1] +
# 1.0 [X0 X3] +
# 1.0 [Y0 Y1] +
# 1.0 [Y0 Y3] +
# 1.0 [Z0 Z1] +
# 1.0 [Z0 Z3] +
# 1.0 [X1 X2] +
# 1.0 [Y1 Y2] +
# 1.0 [Z1 Z2] +
# 1.0 [X2 X3] +
# 1.0 [Y2 Y3] +
# 1.0 [Z2 Z3]

# %%
h2_mol = molecule_example("H2")
